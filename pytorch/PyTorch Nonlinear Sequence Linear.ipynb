# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# %%
# make the original data
series = np.sin((0.1*np.arange(400))**2)

# %%
# plot it
plt.figure(figsize=(12,8))
plt.plot(series)
plt.show()

# %%
# Things you should automatically have memorized
# N = number of samples
# T = sequence length
# D = number of input features
# M = number of hidden units, a hyper parameter you can choose
# K = number of output units

# %%
# build the datase
T = 10
D = 1
X = []
Y = []
for t in range(len(series) - T):
  x = series[t:t+T]
  X.append(x)
  y = series[t+T]
  Y.append(y)

X = np.array(X).reshape(-1,T) # make it N x T
Y = np.array(Y).reshape(-1,1)
N = len(X)
print(f"X.shape: {X.shape}, Y.shape: {Y.shape}")
# Out:
# X.shape: (390, 10), Y.shape: (390, 1)

# %%
# Try autoregressive linear model
model = nn.Linear(T, 1)

# %%
# Loss and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.1)

# %%
# make inputs and targets
X_train = torch.from_numpy(X[:-N//2].astype(np.float32))
y_train = torch.from_numpy(Y[:-N//2].astype(np.float32))
X_test = torch.from_numpy(X[-N//2:].astype(np.float32))
y_test = torch.from_numpy(Y[-N//2:].astype(np.float32))

# %%
def full_gd(model, criterion,
            optimizer, X_train,
            y_train, X_test, y_test, epochs=200):
  # stuff to store
  train_losses = np.zeros(epochs)
  test_losses = np.zeros(epochs)

  for it in range(epochs):
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward paa
    outputs = model(X_train)
    loss = criterion(outputs, y_train)
    # backward and optimize
    loss.backward()
    optimizer.step()
    # save losses
    train_losses[it] = loss.item()
    # test loss
    ouputs_test = model(X_test)
    loss_test = criterion(ouputs_test, y_test)
    test_losses[it] = loss_test.item()
    if (it + 1) % 5 == 0:
      print(f"Epoch {it+1}/{epochs}, Train Loss: {loss.item():.4f}, Test Loss: {loss_test.item():.4f}")
  return train_losses, test_losses

# %%
train_losses, test_losses = full_gd(model,
                                    criterion,
                                    optimizer,
                                    X_train,
                                    y_train,
                                    X_test,
                                    y_test)
# Out:
# Epoch 5/200, Train Loss: 0.5098, Test Loss: 0.6674
# Epoch 10/200, Train Loss: 0.4970, Test Loss: 0.5912
# Epoch 15/200, Train Loss: 0.4941, Test Loss: 0.5944
# Epoch 20/200, Train Loss: 0.4886, Test Loss: 0.6084
# Epoch 25/200, Train Loss: 0.4854, Test Loss: 0.5964
# Epoch 30/200, Train Loss: 0.4859, Test Loss: 0.5822
# Epoch 35/200, Train Loss: 0.4839, Test Loss: 0.5946
# Epoch 40/200, Train Loss: 0.4844, Test Loss: 0.5944
# Epoch 45/200, Train Loss: 0.4838, Test Loss: 0.5873
# Epoch 50/200, Train Loss: 0.4834, Test Loss: 0.5894
# Epoch 55/200, Train Loss: 0.4835, Test Loss: 0.5907
# Epoch 60/200, Train Loss: 0.4834, Test Loss: 0.5889
# Epoch 65/200, Train Loss: 0.4834, Test Loss: 0.5907
# Epoch 70/200, Train Loss: 0.4834, Test Loss: 0.5906
# Epoch 75/200, Train Loss: 0.4833, Test Loss: 0.5891
# Epoch 80/200, Train Loss: 0.4833, Test Loss: 0.5895
# Epoch 85/200, Train Loss: 0.4833, Test Loss: 0.5897
# Epoch 90/200, Train Loss: 0.4833, Test Loss: 0.5894
# Epoch 95/200, Train Loss: 0.4833, Test Loss: 0.5900
# Epoch 100/200, Train Loss: 0.4833, Test Loss: 0.5894
# Epoch 105/200, Train Loss: 0.4833, Test Loss: 0.5899
# Epoch 110/200, Train Loss: 0.4833, Test Loss: 0.5895
# Epoch 115/200, Train Loss: 0.4833, Test Loss: 0.5897
# Epoch 120/200, Train Loss: 0.4833, Test Loss: 0.5896
# Epoch 125/200, Train Loss: 0.4833, Test Loss: 0.5896
# Epoch 130/200, Train Loss: 0.4833, Test Loss: 0.5897
# Epoch 135/200, Train Loss: 0.4833, Test Loss: 0.5896
# Epoch 140/200, Train Loss: 0.4833, Test Loss: 0.5897
# Epoch 145/200, Train Loss: 0.4833, Test Loss: 0.5897
# Epoch 150/200, Train Loss: 0.4833, Test Loss: 0.5897
# Epoch 155/200, Train Loss: 0.4833, Test Loss: 0.5897
# Epoch 160/200, Train Loss: 0.4833, Test Loss: 0.5897
# Epoch 165/200, Train Loss: 0.4833, Test Loss: 0.5897
# Epoch 170/200, Train Loss: 0.4833, Test Loss: 0.5897
# Epoch 175/200, Train Loss: 0.4833, Test Loss: 0.5897
# Epoch 180/200, Train Loss: 0.4833, Test Loss: 0.5897
# Epoch 185/200, Train Loss: 0.4833, Test Loss: 0.5897
# Epoch 190/200, Train Loss: 0.4833, Test Loss: 0.5897
# Epoch 195/200, Train Loss: 0.4833, Test Loss: 0.5897
# Epoch 200/200, Train Loss: 0.4833, Test Loss: 0.5897

# %%
# plot the train loss and test loss per iteration
plt.figure(figsize=(12,10))
plt.plot(train_losses, label='train loss')
plt.plot(test_losses, label='test loss')
plt.legend()
plt.show()

# %%
# One-step forecast using true targets
# Note: even the one-step forecast fails badly
validation_target = Y[-N//2:]
with torch.no_grad():
  validation_predictions = model(X_test).numpy()
# validation_predictions = []
# last train input
# 1-D array of length T
# last_x = torch.from_numpy(X[-N//2].astype(np.float32))
# while len(validation_predictions) < len(validation_target):
#   input_ = last_x.view(1,-1)
#   p = model(input_) # [0,0] 1x1 array -> scalar
#   # update the predictions list
#   validation_predictions.append(p[0,0].item())
#   # make the new input
#   last_x = torch.cat((last_x[1:], p[0]))

# %%
plt.figure(figsize=(12,8))
plt.plot(validation_target, label="forecast target")
plt.plot(validation_predictions, label="forecast prediction")
plt.legend()

# %%
# Multi-step forecast
validation_target = Y[-N//2:]
validation_predictions = []
# last train input
# 1-D array of length T
last_x = torch.from_numpy(X[-N//2].astype(np.float32))
while len(validation_predictions) < len(validation_target):
  input_ = last_x.view(1,-1)
  p = model(input_) # [0,0] 1x1 array -> scalar
  # update the predictions list
  validation_predictions.append(p[0,0].item())
  # make the new input
  last_x = torch.cat((last_x[1:], p[0]))

# %%
plt.figure(figsize=(12,8))
plt.plot(validation_target, label="forecast target")
plt.plot(validation_predictions, label="forecast prediction")
plt.legend()
